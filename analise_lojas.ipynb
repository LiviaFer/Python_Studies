# %% [markdown]
# <a href="https://colab.research.google.com/github/LiviaFer/Python_Studies/blob/main/analise_lojas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %% [markdown]
# ##Carregar a base de dados bruta

# %%
vendas_df = pd.read_csv('/content/Contoso - Vendas - 2017 - Contoso - Vendas - 2017.csv')
produtos_df =pd.read_csv('/content/Contoso - Cadastro Produtos.csv', sep=';')
clientes_df = pd.read_csv('/content/Contoso - Clientes.csv', sep=';')
lojas_df = pd.read_csv('/content/Contoso - Lojas.csv', sep=';' )

display(vendas_df)
display(produtos_df)
display(clientes_df)
display(lojas_df)
# Out:
#         Numero da Venda Data da Venda Data do Envio  ID Canal  ID Loja  \
# 0                     1    01/01/2017    02/01/2017         1     86.0
# 1                     2    01/01/2017    06/01/2017         5    308.0
# 2                     3    01/01/2017    01/01/2017         0    294.0
# 3                     4    01/01/2017    01/01/2017         0    251.0
# 4                     5    01/01/2017    07/01/2017         6     94.0
# ...                 ...           ...           ...       ...      ...
# 102103           102104    12/02/2017    12/02/2017         0    142.0
# 102104           102105    12/02/2017    13/02/2017         1    176.0
# 102105           102106    12/02/2017    13/02/2017         1     48.0
# 102106           102107    12/02/2017    12/02/2017         0    156.0
# 102107           102108    12/02/2017    12/02/2017         0      NaN
#
#         ID Produto  ID Promocao  ID Cliente  Quantidade Vendida  \
# 0            981.0          2.0      6825.0                 9.0
# 1           1586.0          2.0     18469.0                 9.0
# 2           1444.0          5.0     19730.0                13.0
# 3           1468.0          5.0     29326.0                 6.0
# 4           1106.0          2.0     22617.0                 4.0
# ...            ...          ...         ...                 ...
# 102103      1365.0          2.0     23267.0                 9.0
# 102104       780.0          2.0     16531.0                 9.0
# 102105      1052.0          2.0     33056.0                 9.0
# 102106      1532.0          2.0     23147.0                 9.0
# 102107         NaN          NaN         NaN                 NaN
#
#         Quantidade Devolvida
# 0                        1.0
# 1                        1.0
# 2                        1.0
# 3                        1.0
# 4                        1.0
# ...                      ...
# 102103                   0.0
# 102104                   0.0
# 102105                   0.0
# 102106                   0.0
# 102107                   NaN
#
# [102108 rows x 10 columns]
#          Nome da Marca       Tipo Custo Unitario Preco Unitario  ID Produto  \
# 0              Contoso  Econômico          10,69          20,96         873
# 1              Contoso  Econômico           6,63             13         879
# 2              Contoso  Econômico           6,63             13         880
# 3              Contoso  Econômico           6,63             13         881
# 4              Contoso  Econômico           6,63             13         882
# ...                ...        ...            ...            ...         ...
# 1685  Southridge Video    Regular          82,77         179,99        1602
# 1686  Southridge Video    Regular          73,57         159,99        1606
# 1687  Southridge Video    Regular          82,77         179,99        1607
# 1688  Southridge Video    Regular          73,57         159,99        1611
# 1689  Southridge Video    Regular          82,77         179,99        1612
#
#                       Categoria
# 0     Acessório para Computador
# 1     Acessório para Computador
# 2     Acessório para Computador
# 3     Acessório para Computador
# 4     Acessório para Computador
# ...                         ...
# 1685                  Filme DVD
# 1686                  Filme DVD
# 1687                  Filme DVD
# 1688                  Filme DVD
# 1689                  Filme DVD
#
# [1690 rows x 6 columns]
#        ID Cliente Primeiro Nome     Sobrenome                         E-mail  \
# 0               1        Garnet    Lanfranchi    glanfranchi0@mayoclinic.com
# 1               2       Lurette     Roseblade      lroseblade1@bigcartel.com
# 2               3       Glenden     Ishchenko      gishchenko2@moonfruit.com
# 3               4         Baron  Jedrzejewsky    bjedrzejewsky3@e-recht24.de
# 4               5        Sheree      Bredbury       sbredbury4@sitemeter.com
# ...           ...           ...           ...                            ...
# 39499       39500        Brandy      Malhotra    brandy0@adventure-works.com
# 39500       39501        Alicia          Raje   alicia12@adventure-works.com
# 39501       39502        Connie           Rai    connie4@adventure-works.com
# 39502       39503         Shawn          Raji    shawn23@adventure-works.com
# 39503       39504       Lindsey        Sharma  lindsey10@adventure-works.com
#
#           Genero  Numero de Filhos Data de Nascimento  Unnamed: 7  Unnamed: 8  \
# 0       Feminino                 2         12/05/1995         NaN         NaN
# 1       Feminino                 2         30/06/1943         NaN         NaN
# 2      Masculino                 5         09/04/1989         NaN         NaN
# 3      Masculino                 4         17/11/1998         NaN         NaN
# 4       Feminino                 5         08/09/1975         NaN         NaN
# ...          ...               ...                ...         ...         ...
# 39499  Masculino                 3         27/07/1980         NaN         NaN
# 39500   Feminino                 5         10/05/2001         NaN         NaN
# 39501   Feminino                 0         13/02/1997         NaN         NaN
# 39502  Masculino                 1         29/03/2001         NaN         NaN
# 39503   Feminino                 0         19/11/1961         NaN         NaN
#
#        Unnamed: 9  Unnamed: 10
# 0             NaN          NaN
# 1             NaN          NaN
# 2             NaN          NaN
# 3             NaN          NaN
# 4             NaN          NaN
# ...           ...          ...
# 39499         NaN          NaN
# 39500         NaN          NaN
# 39501         NaN          NaN
# 39502         NaN          NaN
# 39503         NaN          NaN
#
# [39504 rows x 11 columns]
#      ID Loja                         Nome da Loja  Quantidade Colaboradores  \
# 0          1           Loja Contoso Seattle No.1                       17.0
# 1          2           Loja Contoso Seattle No.2                       25.0
# 2          3              Loja Contoso Kennewick                       26.0
# 3          4               Loja Contoso Bellevue                       19.0
# 4          5                Loja Contoso Redmond                       33.0
# ..       ...                                  ...                       ...
# 301      306          Loja Contoso Europe Online                        7.0
# 302      307            Loja Contoso Asia Online                        8.0
# 303      308  Loja Contoso North America Reseller                      15.0
# 304      309         Loja Contoso Europe Reseller                      12.0
# 305      310           Loja Contoso Asia Reseller                      17.0
#
#                País
# 0    Estados Unidos
# 1    Estados Unidos
# 2    Estados Unidos
# 3    Estados Unidos
# 4    Estados Unidos
# ..              ...
# 301        Alemanha
# 302           China
# 303  Estados Unidos
# 304          França
# 305           China
#
# [306 rows x 4 columns]

# %%
from google.colab import drive
drive.mount('/content/drive')

# %% [markdown]
# ##Aplicação

# %% [markdown]
# ##Limpeza de Colunas desnecessárias

# %%
vendas_df = vendas_df.drop(['Numero da Venda','Data da Venda','Data do Envio','ID Canal','ID Promocao'], axis=1)
produtos_df = produtos_df[['ID Produto', 'Categoria' ]]
clientes_df = clientes_df[['ID Cliente','E-mail']]
lojas_df = lojas_df[['ID Loja', 'Nome da Loja' ]]

display(lojas_df)
# Out:
#      ID Loja                         Nome da Loja
# 0          1           Loja Contoso Seattle No.1
# 1          2           Loja Contoso Seattle No.2
# 2          3              Loja Contoso Kennewick
# 3          4               Loja Contoso Bellevue
# 4          5                Loja Contoso Redmond
# ..       ...                                  ...
# 301      306          Loja Contoso Europe Online
# 302      307            Loja Contoso Asia Online
# 303      308  Loja Contoso North America Reseller
# 304      309         Loja Contoso Europe Reseller
# 305      310           Loja Contoso Asia Reseller
#
# [306 rows x 2 columns]

# %%
display(vendas_df)
# Out:
#         ID Loja  ID Produto  ID Promocao  ID Cliente  Quantidade Vendida  \
# 0            86         981            2        6825                   9
# 1           268         975            6        6825                   4
# 2           231         997            1        6825                  10
# 3            33        1284            1        6825                   5
# 4            21         568            2        6825                   9
# ...         ...         ...          ...         ...                 ...
# 980637       30         193            4       39194                  13
# 980638      199         209            3         574                  24
# 980639       14         921            4         231                   6
# 980640      212         203           10       38138                   8
# 980641      209         959           10         445                   8
#
#         Quantidade Devolvida                Categoria_x  \
# 0                          1             Câmera Digital
# 1                          0             Câmera Digital
# 2                          0             Câmera Digital
# 3                          0      Acessório para Câmera
# 4                          0                   Projetor
# ...                      ...                        ...
# 980637                     0               Home Theater
# 980638                     0               Home Theater
# 980639                     0  Acessório para Computador
# 980640                     0               Home Theater
# 980641                     0             Câmera Digital
#
#                       Categoria_y                  Categoria  \
# 0                  Câmera Digital             Câmera Digital
# 1                  Câmera Digital             Câmera Digital
# 2                  Câmera Digital             Câmera Digital
# 3           Acessório para Câmera      Acessório para Câmera
# 4                        Projetor                   Projetor
# ...                           ...                        ...
# 980637               Home Theater               Home Theater
# 980638               Home Theater               Home Theater
# 980639  Acessório para Computador  Acessório para Computador
# 980640               Home Theater               Home Theater
# 980641             Câmera Digital             Câmera Digital
#
#                                  E-mail
# 0                rbrumfieldmy@ameblo.jp
# 1                rbrumfieldmy@ameblo.jp
# 2                rbrumfieldmy@ameblo.jp
# 3                rbrumfieldmy@ameblo.jp
# 4                rbrumfieldmy@ameblo.jp
# ...                                 ...
# 980637  alexandra36@adventure-works.com
# 980638                fbyshfx@ameblo.jp
# 980639               tpickwell6e@un.org
# 980640     nicole14@adventure-works.com
# 980641         cpfaffcc@dagondesign.com
#
# [980642 rows x 10 columns]

# %% [markdown]
# ##Agrupar todos os Dataframes

# %%
vendas_df = vendas_df.merge(produtos_df, on='ID Produto')
vendas_df = vendas_df.merge(clientes_df, on='ID Cliente')
vendas_df = vendas_df.merge(lojas_df, on='ID Loja')

display(vendas_df)
# Out:
#         ID Loja  ID Produto  ID Cliente  Quantidade Vendida  \
# 0          86.0       981.0      6825.0                 9.0
# 1          86.0      1039.0     30574.0                 9.0
# 2          86.0       901.0     15742.0                 4.0
# 3          86.0       473.0     17253.0                 4.0
# 4          86.0      1106.0     34115.0                 4.0
# ...         ...         ...         ...                 ...
# 102102     90.0       347.0     15422.0                 9.0
# 102103     90.0       372.0      7432.0                 9.0
# 102104     90.0       355.0     38188.0                 9.0
# 102105     71.0       353.0     12439.0                 9.0
# 102106     71.0       408.0     34945.0                 9.0
#
#         Quantidade Devolvida                  Categoria  \
# 0                        1.0             Câmera Digital
# 1                        0.0             Câmera Digital
# 2                        0.0  Acessório para Computador
# 3                        0.0                    Monitor
# 4                        0.0         Câmera Digital SLR
# ...                      ...                        ...
# 102102                   0.0                     Laptop
# 102103                   1.0                     Laptop
# 102104                   0.0                     Laptop
# 102105                   0.0                     Laptop
# 102106                   0.0                     Laptop
#
#                                E-mail                Nome da Loja
# 0              rbrumfieldmy@ameblo.jp        Loja Contoso Austin
# 1         carrie4@adventure-works.com        Loja Contoso Austin
# 2           gthorbyko@hugedomains.com        Loja Contoso Austin
# 3                   fbrixey74@soup.io        Loja Contoso Austin
# 4       eduardo10@adventure-works.com        Loja Contoso Austin
# ...                               ...                         ...
# 102102              dshutlebs@unc.edu        Loja Contoso Dallas
# 102103     lshambrokec1@shinystat.com        Loja Contoso Dallas
# 102104   hailey37@adventure-works.com        Loja Contoso Dallas
# 102105           jbraidonc8@state.gov  Loja Contoso Russellville
# 102106   rebecca7@adventure-works.com  Loja Contoso Russellville
#
# [102107 rows x 8 columns]

# %% [markdown]
# ###Renomear o e-mail para ficar claro que é do cliente

# %%
vendas_df = vendas_df.rename(columns={'E-mail': 'E-mail do Cliente'})
display(vendas_df)
# Out:
#         ID Loja  ID Produto  ID Cliente  Quantidade Vendida  \
# 0          86.0       981.0      6825.0                 9.0
# 1          86.0      1039.0     30574.0                 9.0
# 2          86.0       901.0     15742.0                 4.0
# 3          86.0       473.0     17253.0                 4.0
# 4          86.0      1106.0     34115.0                 4.0
# ...         ...         ...         ...                 ...
# 102102     90.0       347.0     15422.0                 9.0
# 102103     90.0       372.0      7432.0                 9.0
# 102104     90.0       355.0     38188.0                 9.0
# 102105     71.0       353.0     12439.0                 9.0
# 102106     71.0       408.0     34945.0                 9.0
#
#         Quantidade Devolvida                  Categoria  \
# 0                        1.0             Câmera Digital
# 1                        0.0             Câmera Digital
# 2                        0.0  Acessório para Computador
# 3                        0.0                    Monitor
# 4                        0.0         Câmera Digital SLR
# ...                      ...                        ...
# 102102                   0.0                     Laptop
# 102103                   1.0                     Laptop
# 102104                   0.0                     Laptop
# 102105                   0.0                     Laptop
# 102106                   0.0                     Laptop
#
#                     E-mail do Cliente                Nome da Loja
# 0              rbrumfieldmy@ameblo.jp        Loja Contoso Austin
# 1         carrie4@adventure-works.com        Loja Contoso Austin
# 2           gthorbyko@hugedomains.com        Loja Contoso Austin
# 3                   fbrixey74@soup.io        Loja Contoso Austin
# 4       eduardo10@adventure-works.com        Loja Contoso Austin
# ...                               ...                         ...
# 102102              dshutlebs@unc.edu        Loja Contoso Dallas
# 102103     lshambrokec1@shinystat.com        Loja Contoso Dallas
# 102104   hailey37@adventure-works.com        Loja Contoso Dallas
# 102105           jbraidonc8@state.gov  Loja Contoso Russellville
# 102106   rebecca7@adventure-works.com  Loja Contoso Russellville
#
# [102107 rows x 8 columns]

# %% [markdown]
# ##**Insights**
# #Qual cliente comprou mais vezes?
#
# Uso do método value_counts() para contar quantas vezes o mesmo e-mail aparece no Dataframe e plot() para fazer o gráfico.

# %%
frequencia_cliente = vendas_df['E-mail do Cliente'].value_counts()
display(frequencia_cliente)
frequencia_cliente[:5].plot(figsize=(15,5)) #largura e altura
# Out:
# ebony17@adventure-works.com      14
# abletsoe2i@bloomberg.com         12
# jerome2@adventure-works.com      12
# zachary48@adventure-works.com    12
# brandy7@adventure-works.com      12
#                                  ..
# amilellabg@omniture.com           1
# steve7@adventure-works.com        1
# alyssa15@adventure-works.com      1
# abigail17@adventure-works.com     1
# rebecca7@adventure-works.com      1
# Name: E-mail do Cliente, Length: 33528, dtype: int64
# <Axes: >

# %% [markdown]
# ##Qual foi a loja que mais vendeu?
#
# Uso  do método groupby para fazer o agrupamento de todas as lojas e sum() para somar todas as unidades vendidas

# %%
vendas_loja = vendas_df[['Nome da Loja','Quantidade Vendida']].groupby('Nome da Loja').sum()
display(vendas_loja)
# Out:
#                           Quantidade Vendida
# Nome da Loja
# Loja Contoso Albany                   1913.0
# Loja Contoso Alexandria               2290.0
# Loja Contoso Amsterdam                3096.0
# Loja Contoso Anchorage                2042.0
# Loja Contoso Annapolis                1832.0
# ...                                      ...
# Loja Contoso Yokohama                 2831.0
# Loja Contoso York                     2930.0
# Loja Contoso koln No.1                3276.0
# Loja Contoso koln No.2                3376.0
# Loja Contoso obamberg                 2984.0
#
# [301 rows x 1 columns]

# %% [markdown]
# Ordenar a quantidade de itens vendidos de forma decrescente usando o método sort_values()

# %%
vendas_loja = vendas_loja.sort_values('Quantidade Vendida', ascending= False)
vendas_loja[:5].plot(figsize=(15,5), kind='bar')
# Out:
# <Axes: xlabel='Nome da Loja'>

# %% [markdown]
# Qual produto menos vendeu?
#
# Usando os métodos min() para descobrir o menor valor e idxmin() para descobrir o índice do menor valor.

# %%
menor_venda = vendas_loja.min()
pior_loja = vendas_loja['Quantidade Vendida'].idxmin()
print(menor_venda, pior_loja)
# Out:
# Quantidade Vendida    18.0
# dtype: float64 Loja Contoso Russellville
